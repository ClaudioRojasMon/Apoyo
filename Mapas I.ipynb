# %% [markdown]
# # Visualización de Mapas I

# %% [markdown]
# ## Librerías para Mapas con Python

# %% [markdown]
# ```{table} Algunas librerías de Python para Mapas
# :name: my-table-ref
#
# |  Librería  |  Descripción |
# |:-----:|:-----:|
# | Arcy | Sirve para el análisis espacial, la conversión de datos, la administración y la producción de mapas utilizando los programas SIG de ESRI.|
# | Geopandas|Es un proyecto de código abierto que facilita el trabajo con datos geoespaciales en Python y extiende los tipos de datos utilizados por pandas para permitir operaciones espaciales en tipos geométricos.|
# | Cartopy|Cartopy es un paquete de Python diseñado para el procesamiento de datos geoespaciales con el fin de producir mapas y otros análisis de datos geoespaciales.|
# | GDAL/OGR|Es una biblioteca traductora para formatos de datos geoespaciales raster y vectoriales que se publica bajo una licencia de código abierto de estilo MIT por la Open Source Geospatial Foundation.|
# |Geemap|Es un paquete de Python para el análisis y visualización geoespacial interactivos con Google Earth Engine (GEE), que es una plataforma de computación en la nube con un catálogo de múltiples petabytes de imágenes satelitales y conjuntos de datos geoespaciales.|
# | Geopy|Es una librería que permite acceder a servicios de geocodificación,facilita a desarrolladores de Python localizar las coordenadas de direcciones, ciudades, países y puntos de referencia en todo el mundo mediante geocodificadores de terceros y otras fuentes de datos.|
# ```

# %% [markdown]
# ```{dropdown} Documentación de Librerías para Mapas
#
# - [Arcy](https://desktop.arcgis.com/es/arcmap/latest/analyze/arcpy/what-is-arcpy-.htm)
#
# - [Geopandas](https://geopandas.org/en/stable/)
#
# - [Cartopy](https://scitools.org.uk/cartopy/docs/latest/)
#
# - [GDAL](https://gdal.org/index.html)
#
# - [Geemap](https://geemap.org)
#
# - [Geopy](https://geemap.org)
# ```

# %% [markdown]
# ## Librería Folium

# %% [markdown]
# ```{admonition} ¿Qué es Folium?
# <div align="justify"><strong>Folium</strong> es una biblioteca de Python que se utiliza para la visualización de datos geoespaciales en mapas interactivos. Se basa en la popular biblioteca de <strong>JavaScript Leaflet.js</strong> y permite crear mapas detallados y personalizables de manera sencilla y eficaz.</div>
# ```

# %% [markdown]
# ## Creación de un Mapa

# %%
import folium as fl
import pandas as pd
import geopandas as gpd

# %%
from folium import plugins

# %%
import folium
from folium.plugins import MiniMap
from folium.plugins import FloatImage, Fullscreen

# %% [markdown]
# ```{dropdown} Web de mapas de leaflet con folium
#
# - [Mapas de leaflet en Python con folium](https://python-charts.com/es/espacial/mapas-interactivos-folium/)
#
# - [Folium](https://mappinggis.com/2022/09/folium-utilizando-leaflet-con-python/)
# ```

# %% [markdown]
# ### Mapa Base - Leaflet - OpenStreetMap

# %% [markdown]
# <div align="justify">Por defecto, Folium utiliza OpenStreetMap como mapa base. Pueden elegirse otros mapas base mediante el parámetro tiles, el cual tiene un conjunto de valores predeterminados:</div>
#
# - “OpenStreetMap”
# - “Mapbox Bright”
# - “Mapbox Control Room”
# - “Stamen” ("Terrain", "Toner" y "Watercolor")
# - “Cloudmade” (Requiere una llave del API)
# - “Mapbox” (Requiere una llave del API)
# - “CartoDB” ("positron" y "dark_matter")

# %% [markdown]
# ```{admonition} ¿Qué es OpenStreetMap?
# <div align="justify"><strong>OpenStreetMap (OSM)</strong> es un proyecto colaborativo para crear mapas editables y libres, creado por una comunidad creciente de mappers de todo el mundo. La comunidad de OpenStreetMap es diversa y entusiasta y crece todos los días. Entre los  colaboradores figuran cartógrafos apasionados, profesionales de GIS, ingenieros que hacen funcionar los servidores de OSM, personal humanitario que elabora mapas de zonas de desastre, y muchas personas más..</div>
# ```

# %% [markdown]
# ```{dropdown} Web de OpenStreetMap
#
# [OpenStreetMap](https://www.openstreetmap.org)
# ```

# %%
mapa_base= fl.Map()
mapa_base
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_108c2dbc9b6519f065563bed8e3493a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_108c2dbc9b6519f065563bed8e3493a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_108c2dbc9b6519f065563bed8e3493a3 = L.map(
#                 &quot;map_108c2dbc9b6519f065563bed8e3493a3&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a351ea91251006ec8b4b5c7a5b2cc114 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a351ea91251006ec8b4b5c7a5b2cc114.addTo(map_108c2dbc9b6519f065563bed8e3493a3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa_base.save("001_mapa_base.html")

# %% [markdown]
# ### Latitud - Longitud - Única Ubicación

# %% [markdown]
# ```{admonition} ¿Cómo obtener las coordenadas de un lugar?
# <div align="justify">Para obtener las coordenadas de un lugar solo abre Google Maps, haz clic con el botón derecho en el lugar o en el área del mapa o búscalo en "Buscar lugar". Se abrirá una ventana emergente. Puedes encontrar tu latitud y longitud en formato decimal en la parte superior. Luego haz clic con el botón izquierdo en la latitud y la longitud y la copias automaticamente y la pegas en el algortimo respectivo que estás trabajando.</div>
# ```

# %%
# Colegio San Francisc Javier: -41.48342776832596, -72.88303959993823

CSFJ=fl.Map (location=[-41.485252250380675, -72.89014208945709], zoom_start=18)
CSFJ
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efbc148968becdebb08fbc8334324fe5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efbc148968becdebb08fbc8334324fe5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efbc148968becdebb08fbc8334324fe5 = L.map(
#                 &quot;map_efbc148968becdebb08fbc8334324fe5&quot;,
#                 {
#                     center: [-41.485252250380675, -72.89014208945709],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0dc4fc24aa7cc32e8ee32fcd539a3331 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0dc4fc24aa7cc32e8ee32fcd539a3331.addTo(map_efbc148968becdebb08fbc8334324fe5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CSFJ.save("002_mapa_CSF.html")

# %% [markdown]
# ### Marcador - Circulo - Logo

# %%
CSFJ02=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18)

imagen_01= "/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png"

FloatImage(imagen_01,left=90, bottom=90).add_to(CSFJ02)

fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), tooltip="<b>CSFJ</b>").add_to(CSFJ02)
fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ02)

CSFJ02
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5a03df5d81fce3855d99fa23b424ab7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_1d2e6813389e5943174c0db722a46cbb {
#                         position: absolute;
#                         bottom: 90%;
#                         left: 90%;
#                         }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5a03df5d81fce3855d99fa23b424ab7&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_1d2e6813389e5943174c0db722a46cbb&quot; alt=&quot;float_image&quot;
#                  src=&quot;/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5a03df5d81fce3855d99fa23b424ab7 = L.map(
#                 &quot;map_c5a03df5d81fce3855d99fa23b424ab7&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3c4a8554887ac892f294f971d4500c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d3c4a8554887ac892f294f971d4500c0.addTo(map_c5a03df5d81fce3855d99fa23b424ab7);
#
#
#             var marker_c6516173ef740bd8ad28bce07b3049c7 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_c5a03df5d81fce3855d99fa23b424ab7);
#
#
#             var icon_4b5965e85cca35381dd4417fd81a4665 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c6516173ef740bd8ad28bce07b3049c7.setIcon(icon_4b5965e85cca35381dd4417fd81a4665);
#
#
#             marker_c6516173ef740bd8ad28bce07b3049c7.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_f4dd0316dcfd569282033bf2bcacaab0 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_c5a03df5d81fce3855d99fa23b424ab7);
#
#
#             circle_f4dd0316dcfd569282033bf2bcacaab0.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Si deseas guardar el mapa en formato html en tu computador: CSFJ02.save("002_mapa_CSF.html")

# %% [markdown]
# ### Tipos de Tiles (Teselas):

# %% [markdown]
# ```{admonition} ¿Qué es Tiles?
# <div align="justify">El argumento <strong>tiles</strong> permite especificar diferentes tipos de mapa base, tales como <strong>Stamen Terrain</strong>, <strong>CartoDB Positron</strong>, <strong>stamentoner</strong>, <strong>Cartodb dark_matter</strong>, etc. El valor por defecto es "OpenStreetMap" y puedes encontrar más estilos online.</div>
# ```

# %% [markdown]
# #### Mini Mapa - Tiles - FullScreen

# %%
CSFJ03=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18, tiles="CartoDB Positron") #Revisar porque no siempre el tile funciona
#CSFJ02=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18)

imagen_01= "/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png"

FloatImage(imagen_01,left=90, bottom=90).add_to(CSFJ03)

fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), tooltip="<b>CSFJ</b>").add_to(CSFJ03)
fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ03)

#MiniMap(position="bottomleft",toggle_display= True).add_to(CSFJ02)
MiniMap(position="bottomleft",toggle_display= True, tile_layer="CartoDB Positron").add_to(CSFJ03) #revisar porque no siempre tile funciona


CSFJ03
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a706d7a2ee29528127bf307f3959c8fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_c7b135eda9dfe505ec948719ffd2a098 {
#                         position: absolute;
#                         bottom: 90%;
#                         left: 90%;
#                         }
#                 &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a706d7a2ee29528127bf307f3959c8fe&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_c7b135eda9dfe505ec948719ffd2a098&quot; alt=&quot;float_image&quot;
#                  src=&quot;/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a706d7a2ee29528127bf307f3959c8fe = L.map(
#                 &quot;map_a706d7a2ee29528127bf307f3959c8fe&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f7cc9d57538f35ffcc0e67e76337ba5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7f7cc9d57538f35ffcc0e67e76337ba5.addTo(map_a706d7a2ee29528127bf307f3959c8fe);
#
#
#             var marker_5d4e3a08cd2accad41193967584168c0 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_a706d7a2ee29528127bf307f3959c8fe);
#
#
#             var icon_63997ec36e21c24c2cd9be3c07855029 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5d4e3a08cd2accad41193967584168c0.setIcon(icon_63997ec36e21c24c2cd9be3c07855029);
#
#
#             marker_5d4e3a08cd2accad41193967584168c0.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_66e10c057386377794b215e5b3d6b802 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_a706d7a2ee29528127bf307f3959c8fe);
#
#
#             circle_66e10c057386377794b215e5b3d6b802.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var tile_layer_cc9d20ad222638ab628bd1f7ce6798fd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_62e5ebe476d704a7755651c5c42de9da = new L.Control.MiniMap(
#                 tile_layer_cc9d20ad222638ab628bd1f7ce6798fd,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomleft&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_a706d7a2ee29528127bf307f3959c8fe.addCon

# %%
# Si deseas guardar el mapa en formato html en tu computador: CSFJ03.save("002_mapa_CSF.html")

# %% [markdown]
# #### Menú Tiles Configuración

# %%
CSFJ04=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18, tiles="CartoDB Positron") #Revisar porque no siempre el tile funciona

imagen_01= "/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png"

FloatImage(imagen_01,left=90, bottom=90).add_to(CSFJ04)

fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), tooltip="<b>CSFJ</b>").add_to(CSFJ04)
fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ04)

MiniMap(position="bottomleft",toggle_display= True, tile_layer="CartoDB Positron").add_to(CSFJ04) #revisar porque no siempre tile funciona

fl.TileLayer("Stamen Terrain").add_to(CSFJ04)
fl.TileLayer("stamen toner").add_to(CSFJ04)
fl.TileLayer("CartoDB Positron").add_to(CSFJ04)
fl.TileLayer("stamenwatercolor").add_to(CSFJ04)
fl.TileLayer("OpenStreetMap").add_to(CSFJ04)
fl.TileLayer("Cartodb dark_matter").add_to(CSFJ04)

fl.LayerControl(position="bottomright").add_to(CSFJ04)

CSFJ04
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d14e28954b64cc56f2b73833dc57af35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_bc54f4075cdc27175d19ff7edbba78ae {
#                         position: absolute;
#                         bottom: 90%;
#                         left: 90%;
#                         }
#                 &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d14e28954b64cc56f2b73833dc57af35&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_bc54f4075cdc27175d19ff7edbba78ae&quot; alt=&quot;float_image&quot;
#                  src=&quot;/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d14e28954b64cc56f2b73833dc57af35 = L.map(
#                 &quot;map_d14e28954b64cc56f2b73833dc57af35&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31c03b80b97f538145ac68fe56084311 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_31c03b80b97f538145ac68fe56084311.addTo(map_d14e28954b64cc56f2b73833dc57af35);
#
#
#             var marker_2df3935d12a59c1e7b109d8b06934de6 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_d14e28954b64cc56f2b73833dc57af35);
#
#
#             var icon_ae1636537c3ab2e01780dfd88220c8fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2df3935d12a59c1e7b109d8b06934de6.setIcon(icon_ae1636537c3ab2e01780dfd88220c8fd);
#
#
#             marker_2df3935d12a59c1e7b109d8b06934de6.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_ddfbf8a39dcd587067074953e5735905 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_d14e28954b64cc56f2b73833dc57af35);
#
#
#             circle_ddfbf8a39dcd587067074953e5735905.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var tile_layer_0d287ffea2ace38adfddfdb29bf04b25 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_33dc3bfa7319cb7d160dd2a59bd9d6a5 = new L.Control.MiniMap(
#                 tile_layer_0d287ffea2ace38adfddfdb29bf04b25,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomleft&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_d14e28954b64cc56f2b73833dc57af35.addCon

# %%
# Si deseas guardar el mapa en formato html en tu computador: CSFJ04.save("002_mapa_CSF.html")

# %% [markdown]
# ### Configuración Popup

# %% [markdown]
# ```{admonition} ¿Qué es Popup?
# <div align="justify">El parámetro <strong>popup</strong> se utiliza para especificar una hilera HTML que se desplegará en una ventana emergente al hacer clic sobre el marcador.</div>
# ```

# %%
CSFJ05=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18, tiles="CartoDB Positron") #Revisar porque no siempre el tile funciona

html_001='''
<b style="font-family: Arial; "><b>Lugar: Colegio San Francisco Javier</b><br>
<b style="font-family: Arial; ">Latitud: -41.48342776832596</b><br>
<b style="font-family: Arial; ">Longitud: -72.88303959993823</b><br><br>
<b style="font-family: Arial; ">web: <a href="https://goo.su/tM65oO9" target= "_blank">Colegio San Francisco Javier</b><br><br>
<center><img src="https://goo.su/LFaJ" width=200 height=100></center>

'''

iframe = fl.IFrame(html=html_001,width=300,height=250)


fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), popup=fl.Popup(iframe), tooltip="<b>CSFJ</b>").add_to(CSFJ05)

fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ05)

MiniMap(position="bottomleft",toggle_display= True, tile_layer="CartoDB Positron").add_to(CSFJ05) #revisar porque no siempre tile funciona

fl.TileLayer("Stamen Terrain").add_to(CSFJ05)
fl.TileLayer("stamen toner").add_to(CSFJ05)
fl.TileLayer("CartoDB Positron").add_to(CSFJ05)
fl.TileLayer("stamenwatercolor").add_to(CSFJ05)
fl.TileLayer("OpenStreetMap").add_to(CSFJ05)
fl.TileLayer("Cartodb dark_matter").add_to(CSFJ04)

fl.LayerControl(position="bottomright").add_to(CSFJ05)

CSFJ05
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8da0d57b85293307ce37c6fe3f0e4dff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8da0d57b85293307ce37c6fe3f0e4dff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8da0d57b85293307ce37c6fe3f0e4dff = L.map(
#                 &quot;map_8da0d57b85293307ce37c6fe3f0e4dff&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9f53082cedc85352a6e5ae48f004c74 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b9f53082cedc85352a6e5ae48f004c74.addTo(map_8da0d57b85293307ce37c6fe3f0e4dff);
#
#
#             var marker_fe7ebc90b223af404e37229bd19ccac5 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_8da0d57b85293307ce37c6fe3f0e4dff);
#
#
#             var icon_0b29566169dd43f636085151606fd770 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fe7ebc90b223af404e37229bd19ccac5.setIcon(icon_0b29566169dd43f636085151606fd770);
#
#
#         var popup_9f81871e31262cec78c868e8d6ccaebc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_f15afed3dba7a3f55ccff1bf42a8950e = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_9f81871e31262cec78c868e8d6ccaebc.setContent(i_frame_f15afed3dba7a3f55ccff1bf42a8950e);
#
#
#
#         marker_fe7ebc90b223af404e37229bd19ccac5.bindPopup(popup_9f81871e31262cec78c868e8d6ccaebc)
#         ;
#
#
#
#
#             marker_fe7ebc90b223af404e37229bd19ccac5.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_fb51fee8813c1155be03842ce45cd058 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_8da0d57b85293307ce37c6fe3f0e4dff);
#
#
#             circle_fb51fee8813c1155be03842ce45cd058.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var tile_layer_a52436dd63f604eb4c1ac43906274ef0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_9c0e0a9f01ac3fd84117b1307c635673 = new L.Control.MiniMap(
#                 tile_layer_a52436dd63f604eb4c1ac43906274ef0,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomleft&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_8da0d57b85293307ce37c6fe3f0e4dff.addControl(mini_map_9c0e0a9f01ac3fd84117

# %%
# Si deseas guardar el mapa en formato html en tu computador: 
CSFJ05.save("002_mapa_CSF.html")

# %% [markdown]
# ### Multiples Marcadores

# %%
html_001='''
<b style="font-family: Arial; "><b>Lugar: Colegio San Francisco Javier</b><br>
<b style="font-family: Arial; ">Latitud: -41.48342776832596</b><br>
<b style="font-family: Arial; ">Longitud: -72.88303959993823</b><br><br>
<b style="font-family: Arial; ">web: <a href="https://goo.su/tM65oO9" target= "_blank">Colegio San Francisco Javier</b><br><br>
<center><img src="https://goo.su/LFaJ" width=200 height=100></center>

'''

html_002='''
<b style="font-family: Arial; "><b>Lugar: Universidad San Sebastián</b><br>
<b style="font-family: Arial; ">Latitud: -41.46805828626035</b><br>
<b style="font-family: Arial; ">Longitud: -72.90724385396024</b><br><br>
<b style="font-family: Arial; ">web: <a href="https://onx.la/9f9f9" target= "_blank">Universidad San Sebastián</b><br><br>
<center><img src="https://www.uss.cl" width=200 height=100></center>

'''

html_003='''
<b style="font-family: Arial; "><b>Lugar: Mall Alerce</b><br>
<b style="font-family: Arial; ">Latitud: -41.45911787343535</b><br>
<b style="font-family: Arial; ">Longitud: -72.92277920892815</b><br><br>
<b style="font-family: Arial; ">web: <a href="http://www.pasmar.cl/paseo-alerce/" target= "_blank">Mall Alerce</b><br><br>
<center><img src="https://goo.su/zjBH" width=200 height=100></center>

'''

iframe_1 = fl.IFrame(html=html_001,width=300,height=250)

iframe_2 = fl.IFrame(html=html_002,width=300,height=250)

iframe_3 = fl.IFrame(html=html_003,width=300,height=250)

Centro=fl.Map(location=[-41.45979327156361, -72.92269337820014], zoom_start=18) 


fl.Marker(location=[-41.485252250380675,-72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), popup=fl.Popup(iframe_1), tooltip="<b>CSFJ</b>").add_to(Centro)
fl.Marker(location=[-41.46805828626035,-72.90724385396024], icon=fl.Icon(color="red",icon="tower"), popup=fl.Popup(iframe_2), tooltip="<b>USS</b>").add_to(Centro)
fl.Marker(location=[-41.45911787343535,-72.92277920892815], icon=fl.Icon(color="blue",icon="flag"), popup=fl.Popup(iframe_3), tooltip="<b>Mall</b>").add_to(Centro)



Centro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95b9c24824aa8569f8c1952424006971 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95b9c24824aa8569f8c1952424006971&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95b9c24824aa8569f8c1952424006971 = L.map(
#                 &quot;map_95b9c24824aa8569f8c1952424006971&quot;,
#                 {
#                     center: [-41.45979327156361, -72.92269337820014],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d5104b89e1f1fe1091c5bfa38ba2548 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7d5104b89e1f1fe1091c5bfa38ba2548.addTo(map_95b9c24824aa8569f8c1952424006971);
#
#
#             var marker_2f1391d6e577b2fbe4a9e15d9184d511 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_95b9c24824aa8569f8c1952424006971);
#
#
#             var icon_46ce08c725b8d04ac012792b99b11a07 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2f1391d6e577b2fbe4a9e15d9184d511.setIcon(icon_46ce08c725b8d04ac012792b99b11a07);
#
#
#         var popup_f2c998c4e507ff04d178719bae9d4647 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_caf28b63eb6d648cd1edb6c54c4ebef4 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_f2c998c4e507ff04d178719bae9d4647.setContent(i_frame_caf28b63eb6d648cd1edb6c54c4ebef4);
#
#
#
#         marker_2f1391d6e577b2fbe4a9e15d9184d511.bindPopup(popup_f2c998c4e507ff04d178719bae9d4647)
#         ;
#
#
#
#
#             marker_2f1391d6e577b2fbe4a9e15d9184d511.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_51480269f5e9b865fba2ca202d6ed3dc = L.marker(
#                 [-41.46805828626035, -72.90724385396024],
#                 {}
#             ).addTo(map_95b9c24824aa8569f8c1952424006971);
#
#
#             var icon_569db7d71ea2161d9a562c0893d8b68b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tower&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_51480269f5e9b865fba2ca202d6ed3dc.setIcon(icon_569db7d71ea2161d9a562c0893d8b68b);
#
#
#         var popup_ee13e754b7592fbc40e3e09bf7c8304e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_da05e0baab070714981f722999411ba8 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_ee13e754b7592fbc40e3e09bf7c8304e.setContent(i_frame_da05e0baab070714981f722999411ba8);
#
#
#
#         marker_51480269f5e9b865fba2ca202d6ed3dc.bindPopup(popup_ee13e754b7592fbc40e3e09bf7c8304e)
#         ;
#
#
#
#
#             marker_51480269f5e9b865fba2ca202d6ed3dc.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;USS&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ed7ca78af8faf9c11359412cd4b71c83 = L.marker(
#                 [-41.45911787343535, -72.92277920892815],
#                 {}
#             ).addTo(map_95b9c24824aa8569f8c1952424006971);
#
#
#             var icon_2cd5da48d6d5cf39b5aeb98da3ec9484 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ed7ca78af8faf9c11359412cd4b71c83.setIcon(icon_2cd5da48d6d5cf39b5aeb98da3ec9484);
#
#
#         var popup_8bacd6ad198c82b3d315eb8034fa7061 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_9aa9264e6cfabd86e9506aee7f3ba063 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_8bacd6ad198c8

# %%
# Si deseas guardar el mapa en formato html en tu computador: 
Centro.save("003_mapa_CSF.html")
