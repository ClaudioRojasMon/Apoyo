# %% [markdown]
# # Mapas

# %% [markdown]
# ## Librería Folium

# %% [markdown]
# ```{admonition} ¿Qué es Folium?
# <div align="justify"><strong>Folium</strong> es una biblioteca de Python que se utiliza para la visualización de datos geoespaciales en mapas interactivos. Se basa en la popular biblioteca de <strong>JavaScript Leaflet.js</strong> y permite crear mapas detallados y personalizables de manera sencilla y eficaz.</div>
# ```

# %%
import folium as fl
import pandas as pd
import geopandas as gpd

# %%
from folium import plugins

# %%
import folium
from folium.plugins import MiniMap
from folium.plugins import FloatImage, Fullscreen

# %% [markdown]
# ### Mapa Base - Leaflet - OpenStreetMap

# %%
mapa_base= fl.Map()
mapa_base
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db591e4a2663751972d76f39ce6d9c7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db591e4a2663751972d76f39ce6d9c7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db591e4a2663751972d76f39ce6d9c7a = L.map(
#                 &quot;map_db591e4a2663751972d76f39ce6d9c7a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c58d9fafbbc45ab487465111dea2ee59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c58d9fafbbc45ab487465111dea2ee59.addTo(map_db591e4a2663751972d76f39ce6d9c7a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa_base.save("001_mapa_base.html")

# %% [markdown]
# ### Latitud - Longitud - Única Ubicación

# %%
# Colegio San Francisc Javier: -41.48342776832596, -72.88303959993823

CSFJ=fl.Map (location=[-41.485252250380675, -72.89014208945709], zoom_start=18)
CSFJ
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e50fca4c1af9ccdef15d6079eddaf884 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e50fca4c1af9ccdef15d6079eddaf884&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e50fca4c1af9ccdef15d6079eddaf884 = L.map(
#                 &quot;map_e50fca4c1af9ccdef15d6079eddaf884&quot;,
#                 {
#                     center: [-41.485252250380675, -72.89014208945709],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b74a15f6c12655b62790b89e452f28dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b74a15f6c12655b62790b89e452f28dd.addTo(map_e50fca4c1af9ccdef15d6079eddaf884);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CSFJ.save("002_mapa_CSF.html")

# %% [markdown]
# ### Marcador - Circulo - Logo

# %%
CSFJ02=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18)

imagen_01= "/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png"

FloatImage(imagen_01,left=90, bottom=90).add_to(CSFJ02)

fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), tooltip="<b>CSFJ</b>").add_to(CSFJ02)
fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ02)

CSFJ02
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f463e93089d98b9bfd1b3baba3aabf40 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_5772294a8e3dc22ecaaa0405856dd89a {
#                         position: absolute;
#                         bottom: 90%;
#                         left: 90%;
#                         }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f463e93089d98b9bfd1b3baba3aabf40&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_5772294a8e3dc22ecaaa0405856dd89a&quot; alt=&quot;float_image&quot;
#                  src=&quot;/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f463e93089d98b9bfd1b3baba3aabf40 = L.map(
#                 &quot;map_f463e93089d98b9bfd1b3baba3aabf40&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29f84978f309e78ce2776fc36756c8bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_29f84978f309e78ce2776fc36756c8bc.addTo(map_f463e93089d98b9bfd1b3baba3aabf40);
#
#
#             var marker_ee98a0c01998d03b7d781228cda321a0 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_f463e93089d98b9bfd1b3baba3aabf40);
#
#
#             var icon_e2a4f38a358d1089edabd56b1dab4937 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ee98a0c01998d03b7d781228cda321a0.setIcon(icon_e2a4f38a358d1089edabd56b1dab4937);
#
#
#             marker_ee98a0c01998d03b7d781228cda321a0.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_eefa484cc2cde2ccf3dc02c030cdd273 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_f463e93089d98b9bfd1b3baba3aabf40);
#
#
#             circle_eefa484cc2cde2ccf3dc02c030cdd273.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CSFJ02.save("002_mapa_CSF.html")

# %% [markdown]
# ### Mini Mapa - Tiles - FullScreen

# %% [markdown]
# #### Tipos de Tiles:
#
# El argumento ***tiles*** permite especificar diferentes tipos de mapa base, tales como **"Stamen Terrain"**, **"CartoDB Positron"**, **"stamentoner"**, ***"Cartodb dark_matter"***, etc. El valor por defecto es "OpenStreetMap" y puedes encontrar más estilos online.
#
# Revisar: [Python Charts](https://python-charts.com/es/espacial/mapas-interactivos-folium/)

# %%
CSFJ03=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18, tiles="CartoDB Positron") #Revisar porque no siempre el tile funciona
#CSFJ02=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18)

imagen_01= "/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png"

FloatImage(imagen_01,left=90, bottom=90).add_to(CSFJ03)

fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), tooltip="<b>CSFJ</b>").add_to(CSFJ03)
fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ03)

#MiniMap(position="bottomleft",toggle_display= True).add_to(CSFJ02)
MiniMap(position="bottomleft",toggle_display= True, tile_layer="CartoDB Positron").add_to(CSFJ03) #revisar porque no siempre tile funciona


CSFJ03
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d837c9084ba9dee1a8d1f09e47b6744a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_7e2aba58a0751bf690cabf6f43ee03fe {
#                         position: absolute;
#                         bottom: 90%;
#                         left: 90%;
#                         }
#                 &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d837c9084ba9dee1a8d1f09e47b6744a&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_7e2aba58a0751bf690cabf6f43ee03fe&quot; alt=&quot;float_image&quot;
#                  src=&quot;/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d837c9084ba9dee1a8d1f09e47b6744a = L.map(
#                 &quot;map_d837c9084ba9dee1a8d1f09e47b6744a&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b795213e9edaacb9f358fee282326dff = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b795213e9edaacb9f358fee282326dff.addTo(map_d837c9084ba9dee1a8d1f09e47b6744a);
#
#
#             var marker_f553931ca09d13fdea560d3999b24151 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_d837c9084ba9dee1a8d1f09e47b6744a);
#
#
#             var icon_3cafae5d52a2be2f448898c138f66f12 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f553931ca09d13fdea560d3999b24151.setIcon(icon_3cafae5d52a2be2f448898c138f66f12);
#
#
#             marker_f553931ca09d13fdea560d3999b24151.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_ab3be042a58a08aea2c7dbff561fec9a = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_d837c9084ba9dee1a8d1f09e47b6744a);
#
#
#             circle_ab3be042a58a08aea2c7dbff561fec9a.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var tile_layer_f4295b89f6bc1251c89dba41318a6bf7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_21e2fcbd5ac6759128f5f1e0801540ac = new L.Control.MiniMap(
#                 tile_layer_f4295b89f6bc1251c89dba41318a6bf7,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomleft&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_d837c9084ba9dee1a8d1f09e47b6744a.addCon

# %%
CSFJ03.save("002_mapa_CSF.html")

# %% [markdown]
# #### Menú Tiles Configuración

# %%
CSFJ04=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18, tiles="CartoDB Positron") #Revisar porque no siempre el tile funciona

imagen_01= "/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png"

FloatImage(imagen_01,left=90, bottom=90).add_to(CSFJ04)

fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), tooltip="<b>CSFJ</b>").add_to(CSFJ04)
fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ04)

MiniMap(position="bottomleft",toggle_display= True, tile_layer="CartoDB Positron").add_to(CSFJ04) #revisar porque no siempre tile funciona

fl.TileLayer("Stamen Terrain").add_to(CSFJ04)
fl.TileLayer("stamen toner").add_to(CSFJ04)
fl.TileLayer("CartoDB Positron").add_to(CSFJ04)
fl.TileLayer("stamenwatercolor").add_to(CSFJ04)
fl.TileLayer("OpenStreetMap").add_to(CSFJ04)
fl.TileLayer("Cartodb dark_matter").add_to(CSFJ04)

fl.LayerControl(position="bottomright").add_to(CSFJ04)

CSFJ04
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81d90587265cdcd86ab1c3f4db93b5f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_07b69d122c6ca60b7d7f3776f35d0ae9 {
#                         position: absolute;
#                         bottom: 90%;
#                         left: 90%;
#                         }
#                 &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81d90587265cdcd86ab1c3f4db93b5f3&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_07b69d122c6ca60b7d7f3776f35d0ae9&quot; alt=&quot;float_image&quot;
#                  src=&quot;/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81d90587265cdcd86ab1c3f4db93b5f3 = L.map(
#                 &quot;map_81d90587265cdcd86ab1c3f4db93b5f3&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e543d4ac1f3c5be2d5fea04ca8b15b9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0e543d4ac1f3c5be2d5fea04ca8b15b9.addTo(map_81d90587265cdcd86ab1c3f4db93b5f3);
#
#
#             var marker_98bd9aaaa1a899d86f6fece1fca8037a = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_81d90587265cdcd86ab1c3f4db93b5f3);
#
#
#             var icon_914398ada3eebb6d600f62c81bcbdf1a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_98bd9aaaa1a899d86f6fece1fca8037a.setIcon(icon_914398ada3eebb6d600f62c81bcbdf1a);
#
#
#             marker_98bd9aaaa1a899d86f6fece1fca8037a.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_8b5104cea0e09547c7fa195bedbe34e0 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_81d90587265cdcd86ab1c3f4db93b5f3);
#
#
#             circle_8b5104cea0e09547c7fa195bedbe34e0.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var tile_layer_dcaf3fc029c2a83bd4cccbb7bd22040c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_9c5c1411e016ca91dcbc91e9d76dc911 = new L.Control.MiniMap(
#                 tile_layer_dcaf3fc029c2a83bd4cccbb7bd22040c,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomleft&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_81d90587265cdcd86ab1c3f4db93b5f3.addCon

# %%
CSFJ04.save("002_mapa_CSF.html")

# %% [markdown]
# ### Configuración Popup

# %%
CSFJ05=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18, tiles="CartoDB Positron") #Revisar porque no siempre el tile funciona

html_001='''
<b style="font-family: Arial; "><b>Lugar: Colegio San Francisco Javier</b><br>
<b style="font-family: Arial; ">Latitud: -41.48342776832596</b><br>
<b style="font-family: Arial; ">Longitud: -72.88303959993823</b><br><br>
<b style="font-family: Arial; ">web: <a href="https://goo.su/tM65oO9" target= "_blank">Colegio San Francisco Javier</b><br><br>
<center><img src="https://goo.su/LFaJ" width=200 height=100></center>

'''

iframe = fl.IFrame(html=html_001,width=300,height=250)


fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), popup=fl.Popup(iframe), tooltip="<b>CSFJ</b>").add_to(CSFJ05)

fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ05)

MiniMap(position="bottomleft",toggle_display= True, tile_layer="CartoDB Positron").add_to(CSFJ05) #revisar porque no siempre tile funciona

fl.TileLayer("Stamen Terrain").add_to(CSFJ05)
fl.TileLayer("stamen toner").add_to(CSFJ05)
fl.TileLayer("CartoDB Positron").add_to(CSFJ05)
fl.TileLayer("stamenwatercolor").add_to(CSFJ05)
fl.TileLayer("OpenStreetMap").add_to(CSFJ05)
fl.TileLayer("Cartodb dark_matter").add_to(CSFJ04)

fl.LayerControl(position="bottomright").add_to(CSFJ05)

CSFJ05
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e3d77977ec0c1f9f2d946e933dae512 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e3d77977ec0c1f9f2d946e933dae512&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e3d77977ec0c1f9f2d946e933dae512 = L.map(
#                 &quot;map_1e3d77977ec0c1f9f2d946e933dae512&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_591650c8c451b3d9176677e11e38f555 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_591650c8c451b3d9176677e11e38f555.addTo(map_1e3d77977ec0c1f9f2d946e933dae512);
#
#
#             var marker_a5cd9a62fd908739c8b2bdff5ec3151a = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_1e3d77977ec0c1f9f2d946e933dae512);
#
#
#             var icon_6d18e7c593ded99ea85028f0eb445c4f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a5cd9a62fd908739c8b2bdff5ec3151a.setIcon(icon_6d18e7c593ded99ea85028f0eb445c4f);
#
#
#         var popup_e0aa3f6487fdde3588fd736e8e83a97f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_f33cb0aff4991829d0b12b6094624b66 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_e0aa3f6487fdde3588fd736e8e83a97f.setContent(i_frame_f33cb0aff4991829d0b12b6094624b66);
#
#
#
#         marker_a5cd9a62fd908739c8b2bdff5ec3151a.bindPopup(popup_e0aa3f6487fdde3588fd736e8e83a97f)
#         ;
#
#
#
#
#             marker_a5cd9a62fd908739c8b2bdff5ec3151a.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_53e7a148d1e59261089e27e0ac4dfea4 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_1e3d77977ec0c1f9f2d946e933dae512);
#
#
#             circle_53e7a148d1e59261089e27e0ac4dfea4.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var tile_layer_db641a6e5bc820411dd2edcf81cfe82e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_07b43542fdf75c0f35b7baf7f913746f = new L.Control.MiniMap(
#                 tile_layer_db641a6e5bc820411dd2edcf81cfe82e,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomleft&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_1e3d77977ec0c1f9f2d946e933dae512.addControl(mini_map_07b43542fdf75c0f35b7

# %%
CSFJ05.save("002_mapa_CSF.html")

# %% [markdown]
# ### Multiples Marcadores  Caso I

# %%
html_001='''
<b style="font-family: Arial; "><b>Lugar: Colegio San Francisco Javier</b><br>
<b style="font-family: Arial; ">Latitud: -41.48342776832596</b><br>
<b style="font-family: Arial; ">Longitud: -72.88303959993823</b><br><br>
<b style="font-family: Arial; ">web: <a href="https://goo.su/tM65oO9" target= "_blank">Colegio San Francisco Javier</b><br><br>
<center><img src="https://goo.su/LFaJ" width=200 height=100></center>

'''

html_002='''
<b style="font-family: Arial; "><b>Lugar: Universidad San Sebastián</b><br>
<b style="font-family: Arial; ">Latitud: -41.46805828626035</b><br>
<b style="font-family: Arial; ">Longitud: -72.90724385396024</b><br><br>
<b style="font-family: Arial; ">web: <a href="https://onx.la/9f9f9" target= "_blank">Universidad San Sebastián</b><br><br>
<center><img src="https://www.uss.cl" width=200 height=100></center>

'''

html_003='''
<b style="font-family: Arial; "><b>Lugar: Mall Alerce</b><br>
<b style="font-family: Arial; ">Latitud: -41.45911787343535</b><br>
<b style="font-family: Arial; ">Longitud: -72.92277920892815</b><br><br>
<b style="font-family: Arial; ">web: <a href="http://www.pasmar.cl/paseo-alerce/" target= "_blank">Mall Alerce</b><br><br>
<center><img src="https://goo.su/zjBH" width=200 height=100></center>

'''

iframe_1 = fl.IFrame(html=html_001,width=300,height=250)

iframe_2 = fl.IFrame(html=html_002,width=300,height=250)

iframe_3 = fl.IFrame(html=html_003,width=300,height=250)

Centro=fl.Map(location=[-41.45979327156361, -72.92269337820014], zoom_start=18) 


fl.Marker(location=[-41.485252250380675,-72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), popup=fl.Popup(iframe_1), tooltip="<b>CSFJ</b>").add_to(Centro)
fl.Marker(location=[-41.46805828626035,-72.90724385396024], icon=fl.Icon(color="red",icon="tower"), popup=fl.Popup(iframe_2), tooltip="<b>USS</b>").add_to(Centro)
fl.Marker(location=[-41.45911787343535,-72.92277920892815], icon=fl.Icon(color="blue",icon="flag"), popup=fl.Popup(iframe_3), tooltip="<b>Mall</b>").add_to(Centro)



Centro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ca6af55c4ddb36d8f37a5e65a7870c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ca6af55c4ddb36d8f37a5e65a7870c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ca6af55c4ddb36d8f37a5e65a7870c0 = L.map(
#                 &quot;map_0ca6af55c4ddb36d8f37a5e65a7870c0&quot;,
#                 {
#                     center: [-41.45979327156361, -72.92269337820014],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e9c122a78fe231e028eafc5cda96e71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6e9c122a78fe231e028eafc5cda96e71.addTo(map_0ca6af55c4ddb36d8f37a5e65a7870c0);
#
#
#             var marker_75aca7c2511ef2b017013d384c9233e3 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_0ca6af55c4ddb36d8f37a5e65a7870c0);
#
#
#             var icon_cb15735b436e4e508761b638974d7496 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_75aca7c2511ef2b017013d384c9233e3.setIcon(icon_cb15735b436e4e508761b638974d7496);
#
#
#         var popup_5d867564673c72435220f2974efb0d42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_0bc81f24ba13c62ebb1c7aa780c775dc = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_5d867564673c72435220f2974efb0d42.setContent(i_frame_0bc81f24ba13c62ebb1c7aa780c775dc);
#
#
#
#         marker_75aca7c2511ef2b017013d384c9233e3.bindPopup(popup_5d867564673c72435220f2974efb0d42)
#         ;
#
#
#
#
#             marker_75aca7c2511ef2b017013d384c9233e3.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8f982cb5118a77915f7fa5da29e65f99 = L.marker(
#                 [-41.46805828626035, -72.90724385396024],
#                 {}
#             ).addTo(map_0ca6af55c4ddb36d8f37a5e65a7870c0);
#
#
#             var icon_f01a5f242de55e43b7e642ffcf9cdb63 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tower&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8f982cb5118a77915f7fa5da29e65f99.setIcon(icon_f01a5f242de55e43b7e642ffcf9cdb63);
#
#
#         var popup_9ffc4f394b9d0fbdab169b63ea673508 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_7ce5845f48c9037bfa8b81b4cabcef60 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_9ffc4f394b9d0fbdab169b63ea673508.setContent(i_frame_7ce5845f48c9037bfa8b81b4cabcef60);
#
#
#
#         marker_8f982cb5118a77915f7fa5da29e65f99.bindPopup(popup_9ffc4f394b9d0fbdab169b63ea673508)
#         ;
#
#
#
#
#             marker_8f982cb5118a77915f7fa5da29e65f99.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;USS&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_060deb5587aa69154fae187a7caae37c = L.marker(
#                 [-41.45911787343535, -72.92277920892815],
#                 {}
#             ).addTo(map_0ca6af55c4ddb36d8f37a5e65a7870c0);
#
#
#             var icon_94551743322fe512d50b114c44396008 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_060deb5587aa69154fae187a7caae37c.setIcon(icon_94551743322fe512d50b114c44396008);
#
#
#         var popup_64bdea6ec95ecc684be21f9d20222b3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_3016473fec9ae48a4530c6ba3f078304 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_64bdea6ec95ec

# %%
Centro.save("003_mapa_CSF.html")
