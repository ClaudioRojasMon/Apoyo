# %% [markdown]
# # Mapas

# %% [markdown]
# ## Librería Folium

# %% [markdown]
# ```{admonition} ¿Qué es Folium?
# <div align="justify"><strong>Folium</strong> es una biblioteca de Python que se utiliza para la visualización de datos geoespaciales en mapas interactivos. Se basa en la popular biblioteca de <strong>JavaScript Leaflet.js</strong> y permite crear mapas detallados y personalizables de manera sencilla y eficaz.</div>
# ```

# %%
import folium as fl
import pandas as pd
import geopandas as gpd

# %%
from folium import plugins

# %%
import folium
from folium.plugins import MiniMap
from folium.plugins import FloatImage, Fullscreen

# %% [markdown]
# ### Mapa Base - Leaflet - OpenStreetMap

# %%
mapa_base= fl.Map()
mapa_base
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0bea62596d0dbf70fc4585319f692e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0bea62596d0dbf70fc4585319f692e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0bea62596d0dbf70fc4585319f692e1 = L.map(
#                 &quot;map_d0bea62596d0dbf70fc4585319f692e1&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37d6a317eafd96e77b0df05673739df6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_37d6a317eafd96e77b0df05673739df6.addTo(map_d0bea62596d0dbf70fc4585319f692e1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa_base.save("001_mapa_base.html")

# %% [markdown]
# ### Latitud - Longitud - Única Ubicación

# %%
# Colegio San Francisc Javier: -41.48342776832596, -72.88303959993823

CSFJ=fl.Map (location=[-41.485252250380675, -72.89014208945709], zoom_start=18)
CSFJ
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_baf850a2b10bc80e7d7e4d73b2f2c6ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_baf850a2b10bc80e7d7e4d73b2f2c6ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_baf850a2b10bc80e7d7e4d73b2f2c6ba = L.map(
#                 &quot;map_baf850a2b10bc80e7d7e4d73b2f2c6ba&quot;,
#                 {
#                     center: [-41.485252250380675, -72.89014208945709],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c152290cca27ecc8c1a3aa8029b6819f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c152290cca27ecc8c1a3aa8029b6819f.addTo(map_baf850a2b10bc80e7d7e4d73b2f2c6ba);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CSFJ.save("002_mapa_CSF.html")

# %% [markdown]
# ### Marcador - Circulo - Logo

# %%
CSFJ02=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18)

imagen_01= "/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png"

FloatImage(imagen_01,left=90, bottom=90).add_to(CSFJ02)

fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), tooltip="<b>CSFJ</b>").add_to(CSFJ02)
fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ02)

CSFJ02
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57b4ba21e9aa38320a8890599908150f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_630ab9d31a0b05e92082241bd2704002 {
#                         position: absolute;
#                         bottom: 90%;
#                         left: 90%;
#                         }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57b4ba21e9aa38320a8890599908150f&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_630ab9d31a0b05e92082241bd2704002&quot; alt=&quot;float_image&quot;
#                  src=&quot;/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57b4ba21e9aa38320a8890599908150f = L.map(
#                 &quot;map_57b4ba21e9aa38320a8890599908150f&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96d5c562f4731399d4afaf42aa7b4ca0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_96d5c562f4731399d4afaf42aa7b4ca0.addTo(map_57b4ba21e9aa38320a8890599908150f);
#
#
#             var marker_0b7df43052386371ce0cb36612279b40 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_57b4ba21e9aa38320a8890599908150f);
#
#
#             var icon_459016dedb76bd204f4901612592eafc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0b7df43052386371ce0cb36612279b40.setIcon(icon_459016dedb76bd204f4901612592eafc);
#
#
#             marker_0b7df43052386371ce0cb36612279b40.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_1ef68f5a548496cc083735af2eb9dee7 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_57b4ba21e9aa38320a8890599908150f);
#
#
#             circle_1ef68f5a548496cc083735af2eb9dee7.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CSFJ02.save("002_mapa_CSF.html")

# %% [markdown]
# ### Mini Mapa - Tiles - FullScreen

# %% [markdown]
# #### Tipos de Tiles:
#
# El argumento ***tiles*** permite especificar diferentes tipos de mapa base, tales como **"Stamen Terrain"**, **"CartoDB Positron"**, **"stamentoner"**, ***"Cartodb dark_matter"***, etc. El valor por defecto es "OpenStreetMap" y puedes encontrar más estilos online.
#
# Revisar: [Python Charts](https://python-charts.com/es/espacial/mapas-interactivos-folium/)

# %%
CSFJ03=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18, tiles="CartoDB Positron") #Revisar porque no siempre el tile funciona
#CSFJ02=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18)

imagen_01= "/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png"

FloatImage(imagen_01,left=90, bottom=90).add_to(CSFJ03)

fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), tooltip="<b>CSFJ</b>").add_to(CSFJ03)
fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ03)

#MiniMap(position="bottomleft",toggle_display= True).add_to(CSFJ02)
MiniMap(position="bottomleft",toggle_display= True, tile_layer="CartoDB Positron").add_to(CSFJ03) #revisar porque no siempre tile funciona


CSFJ03
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23cefdcc658ff2eaa4875cc7c4e34b92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_4a0e8687dda96f315efdab8b101fea59 {
#                         position: absolute;
#                         bottom: 90%;
#                         left: 90%;
#                         }
#                 &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23cefdcc658ff2eaa4875cc7c4e34b92&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_4a0e8687dda96f315efdab8b101fea59&quot; alt=&quot;float_image&quot;
#                  src=&quot;/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23cefdcc658ff2eaa4875cc7c4e34b92 = L.map(
#                 &quot;map_23cefdcc658ff2eaa4875cc7c4e34b92&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cce9a38f0215d771913e435579ff6e9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2cce9a38f0215d771913e435579ff6e9.addTo(map_23cefdcc658ff2eaa4875cc7c4e34b92);
#
#
#             var marker_5833ab0a8f31ec488f61791b1c30dab4 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_23cefdcc658ff2eaa4875cc7c4e34b92);
#
#
#             var icon_d85a751de5c2ef0c3595c2db8541b726 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5833ab0a8f31ec488f61791b1c30dab4.setIcon(icon_d85a751de5c2ef0c3595c2db8541b726);
#
#
#             marker_5833ab0a8f31ec488f61791b1c30dab4.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_34f243b31b87e66680a6ef05b4430243 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_23cefdcc658ff2eaa4875cc7c4e34b92);
#
#
#             circle_34f243b31b87e66680a6ef05b4430243.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var tile_layer_b8682e8046455a538af16df0f65f601b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_6fb6b16c3f7b39b587f07ccb7f319daf = new L.Control.MiniMap(
#                 tile_layer_b8682e8046455a538af16df0f65f601b,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomleft&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_23cefdcc658ff2eaa4875cc7c4e34b92.addCon

# %%
CSFJ03.save("002_mapa_CSF.html")

# %% [markdown]
# #### Menú Tiles Configuración

# %%
CSFJ04=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18, tiles="CartoDB Positron") #Revisar porque no siempre el tile funciona

imagen_01= "/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png"

FloatImage(imagen_01,left=90, bottom=90).add_to(CSFJ04)

fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), tooltip="<b>CSFJ</b>").add_to(CSFJ04)
fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ04)

MiniMap(position="bottomleft",toggle_display= True, tile_layer="CartoDB Positron").add_to(CSFJ04) #revisar porque no siempre tile funciona

fl.TileLayer("Stamen Terrain").add_to(CSFJ04)
fl.TileLayer("stamen toner").add_to(CSFJ04)
fl.TileLayer("CartoDB Positron").add_to(CSFJ04)
fl.TileLayer("stamenwatercolor").add_to(CSFJ04)
fl.TileLayer("OpenStreetMap").add_to(CSFJ04)
fl.TileLayer("Cartodb dark_matter").add_to(CSFJ04)

fl.LayerControl(position="bottomright").add_to(CSFJ04)

CSFJ04
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_807d6845bbb73a4c7556c189ce07ec9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     #float_image_e44f2ae2b9871880063578f203795468 {
#                         position: absolute;
#                         bottom: 90%;
#                         left: 90%;
#                         }
#                 &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_807d6845bbb73a4c7556c189ce07ec9d&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_e44f2ae2b9871880063578f203795468&quot; alt=&quot;float_image&quot;
#                  src=&quot;/Users/claudiorojas/Documents/Consultora Iteracion Data Science/Logos/Fiverr Premium Kit v2 Iteracion/PNG Logo Files/Transparent Logo.png&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_807d6845bbb73a4c7556c189ce07ec9d = L.map(
#                 &quot;map_807d6845bbb73a4c7556c189ce07ec9d&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1bd88f530d6cbb38be4bfa4fb3f6710 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c1bd88f530d6cbb38be4bfa4fb3f6710.addTo(map_807d6845bbb73a4c7556c189ce07ec9d);
#
#
#             var marker_6760842cc465b7431e57c10a8bb79c3e = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_807d6845bbb73a4c7556c189ce07ec9d);
#
#
#             var icon_66bbba657e6e6cd3cc8065694342ca1d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6760842cc465b7431e57c10a8bb79c3e.setIcon(icon_66bbba657e6e6cd3cc8065694342ca1d);
#
#
#             marker_6760842cc465b7431e57c10a8bb79c3e.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_14c08f7a68b179eb274dfc73fa4dee78 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_807d6845bbb73a4c7556c189ce07ec9d);
#
#
#             circle_14c08f7a68b179eb274dfc73fa4dee78.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var tile_layer_3c3db607b8d396f2c839746f33b00b93 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_bb3ec1d89d380e82102c9c251946edd9 = new L.Control.MiniMap(
#                 tile_layer_3c3db607b8d396f2c839746f33b00b93,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomleft&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_807d6845bbb73a4c7556c189ce07ec9d.addCon

# %%
CSFJ04.save("002_mapa_CSF.html")

# %% [markdown]
# ### Configuración Popup

# %%
CSFJ05=fl.Map(location=[-41.48342776832596, -72.88303959993823], zoom_start=18, tiles="CartoDB Positron") #Revisar porque no siempre el tile funciona

html_001='''
<b style="font-family: Arial; "><b>Lugar: Colegio San Francisco Javier</b><br>
<b style="font-family: Arial; ">Latitud: -41.48342776832596</b><br>
<b style="font-family: Arial; ">Longitud: -72.88303959993823</b><br><br>
<b style="font-family: Arial; ">web: <a href="https://goo.su/tM65oO9" target= "_blank">Colegio San Francisco Javier</b><br><br>
<center><img src="https://goo.su/LFaJ" width=200 height=100></center>

'''

iframe = fl.IFrame(html=html_001,width=300,height=250)


fl.Marker(location=[-41.485252250380675, -72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), popup=fl.Popup(iframe), tooltip="<b>CSFJ</b>").add_to(CSFJ05)

fl.Circle(location=[-41.485252250380675, -72.89014208945709], color="orange",fill_color="red",weight=10, fill_opacity=0.4, tooltip="Jesuitas").add_to(CSFJ05)

MiniMap(position="bottomleft",toggle_display= True, tile_layer="CartoDB Positron").add_to(CSFJ05) #revisar porque no siempre tile funciona

fl.TileLayer("Stamen Terrain").add_to(CSFJ05)
fl.TileLayer("stamen toner").add_to(CSFJ05)
fl.TileLayer("CartoDB Positron").add_to(CSFJ05)
fl.TileLayer("stamenwatercolor").add_to(CSFJ05)
fl.TileLayer("OpenStreetMap").add_to(CSFJ05)
fl.TileLayer("Cartodb dark_matter").add_to(CSFJ04)

fl.LayerControl(position="bottomright").add_to(CSFJ05)

CSFJ05
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb5e81bd15175c46cb53fcf58fbdb4fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb5e81bd15175c46cb53fcf58fbdb4fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb5e81bd15175c46cb53fcf58fbdb4fb = L.map(
#                 &quot;map_eb5e81bd15175c46cb53fcf58fbdb4fb&quot;,
#                 {
#                     center: [-41.48342776832596, -72.88303959993823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b51c5d001f29d2dd06f1a962c6300c6c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b51c5d001f29d2dd06f1a962c6300c6c.addTo(map_eb5e81bd15175c46cb53fcf58fbdb4fb);
#
#
#             var marker_15a57ba1b38b9ae877d695579533f34a = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_eb5e81bd15175c46cb53fcf58fbdb4fb);
#
#
#             var icon_02b4c976372f74b81bcd50f91965690c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_15a57ba1b38b9ae877d695579533f34a.setIcon(icon_02b4c976372f74b81bcd50f91965690c);
#
#
#         var popup_24a56c3d120ebdb50f66f718978041a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_82d1591151d74566c1b986182a990d6d = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_24a56c3d120ebdb50f66f718978041a2.setContent(i_frame_82d1591151d74566c1b986182a990d6d);
#
#
#
#         marker_15a57ba1b38b9ae877d695579533f34a.bindPopup(popup_24a56c3d120ebdb50f66f718978041a2)
#         ;
#
#
#
#
#             marker_15a57ba1b38b9ae877d695579533f34a.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_ae01251f66c957b03bc73ea62f9e2bc5 = L.circle(
#                 [-41.485252250380675, -72.89014208945709],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_eb5e81bd15175c46cb53fcf58fbdb4fb);
#
#
#             circle_ae01251f66c957b03bc73ea62f9e2bc5.bindTooltip(
#                 `&lt;div&gt;
#                      Jesuitas
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var tile_layer_cb5e1b9a6585fe8942fd5eaf3f5f68ab = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_5ee120a3209f941705e0209cbd287bb6 = new L.Control.MiniMap(
#                 tile_layer_cb5e1b9a6585fe8942fd5eaf3f5f68ab,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomleft&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_eb5e81bd15175c46cb53fcf58fbdb4fb.addControl(mini_map_5ee120a3209f941705e0

# %%
CSFJ05.save("002_mapa_CSF.html")

# %% [markdown]
# ### Multiples Marcadores  Caso I

# %%
html_001='''
<b style="font-family: Arial; "><b>Lugar: Colegio San Francisco Javier</b><br>
<b style="font-family: Arial; ">Latitud: -41.48342776832596</b><br>
<b style="font-family: Arial; ">Longitud: -72.88303959993823</b><br><br>
<b style="font-family: Arial; ">web: <a href="https://goo.su/tM65oO9" target= "_blank">Colegio San Francisco Javier</b><br><br>
<center><img src="https://goo.su/LFaJ" width=200 height=100></center>

'''

html_002='''
<b style="font-family: Arial; "><b>Lugar: Universidad San Sebastián</b><br>
<b style="font-family: Arial; ">Latitud: -41.46805828626035</b><br>
<b style="font-family: Arial; ">Longitud: -72.90724385396024</b><br><br>
<b style="font-family: Arial; ">web: <a href="https://onx.la/9f9f9" target= "_blank">Universidad San Sebastián</b><br><br>
<center><img src="https://www.uss.cl" width=200 height=100></center>

'''

html_003='''
<b style="font-family: Arial; "><b>Lugar: Mall Alerce</b><br>
<b style="font-family: Arial; ">Latitud: -41.45911787343535</b><br>
<b style="font-family: Arial; ">Longitud: -72.92277920892815</b><br><br>
<b style="font-family: Arial; ">web: <a href="http://www.pasmar.cl/paseo-alerce/" target= "_blank">Mall Alerce</b><br><br>
<center><img src="https://goo.su/zjBH" width=200 height=100></center>

'''

iframe_1 = fl.IFrame(html=html_001,width=300,height=250)

iframe_2 = fl.IFrame(html=html_002,width=300,height=250)

iframe_3 = fl.IFrame(html=html_003,width=300,height=250)

Centro=fl.Map(location=[-41.45979327156361, -72.92269337820014], zoom_start=18) 


fl.Marker(location=[-41.485252250380675,-72.89014208945709], icon=fl.Icon(color="purple",icon="heart"), popup=fl.Popup(iframe_1), tooltip="<b>CSFJ</b>").add_to(Centro)
fl.Marker(location=[-41.46805828626035,-72.90724385396024], icon=fl.Icon(color="red",icon="tower"), popup=fl.Popup(iframe_2), tooltip="<b>USS</b>").add_to(Centro)
fl.Marker(location=[-41.45911787343535,-72.92277920892815], icon=fl.Icon(color="blue",icon="flag"), popup=fl.Popup(iframe_3), tooltip="<b>Mall</b>").add_to(Centro)



Centro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47eed47009b494f221bb010a3e676a2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47eed47009b494f221bb010a3e676a2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47eed47009b494f221bb010a3e676a2c = L.map(
#                 &quot;map_47eed47009b494f221bb010a3e676a2c&quot;,
#                 {
#                     center: [-41.45979327156361, -72.92269337820014],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb55960f037688fac9d20f1ed702f758 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bb55960f037688fac9d20f1ed702f758.addTo(map_47eed47009b494f221bb010a3e676a2c);
#
#
#             var marker_12652dfc6005ab58d2ca1c2dc09ef034 = L.marker(
#                 [-41.485252250380675, -72.89014208945709],
#                 {}
#             ).addTo(map_47eed47009b494f221bb010a3e676a2c);
#
#
#             var icon_2f1433342cdc364223c934582344292b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_12652dfc6005ab58d2ca1c2dc09ef034.setIcon(icon_2f1433342cdc364223c934582344292b);
#
#
#         var popup_91bb6e0c2a8d608067107d0fc67cad16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_9094de8e3cf3225701611f624baff684 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_91bb6e0c2a8d608067107d0fc67cad16.setContent(i_frame_9094de8e3cf3225701611f624baff684);
#
#
#
#         marker_12652dfc6005ab58d2ca1c2dc09ef034.bindPopup(popup_91bb6e0c2a8d608067107d0fc67cad16)
#         ;
#
#
#
#
#             marker_12652dfc6005ab58d2ca1c2dc09ef034.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;CSFJ&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_27b7427998e6657ffad20866e0620230 = L.marker(
#                 [-41.46805828626035, -72.90724385396024],
#                 {}
#             ).addTo(map_47eed47009b494f221bb010a3e676a2c);
#
#
#             var icon_ca09c794d750a4146f0384fc6b3b310e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tower&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_27b7427998e6657ffad20866e0620230.setIcon(icon_ca09c794d750a4146f0384fc6b3b310e);
#
#
#         var popup_2dfec332a63013391eb320e8099094b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_58fb5a3fba80e4cae58918d200a6b83f = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_2dfec332a63013391eb320e8099094b9.setContent(i_frame_58fb5a3fba80e4cae58918d200a6b83f);
#
#
#
#         marker_27b7427998e6657ffad20866e0620230.bindPopup(popup_2dfec332a63013391eb320e8099094b9)
#         ;
#
#
#
#
#             marker_27b7427998e6657ffad20866e0620230.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;USS&lt;/b&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_be07c3e20509ac129974007bae086583 = L.marker(
#                 [-41.45911787343535, -72.92277920892815],
#                 {}
#             ).addTo(map_47eed47009b494f221bb010a3e676a2c);
#
#
#             var icon_50012e51aca26b48b88be9c2f6a87ada = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_be07c3e20509ac129974007bae086583.setIcon(icon_50012e51aca26b48b88be9c2f6a87ada);
#
#
#         var popup_ebfef0737aead44cde16ec991358ea29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_fceaa090c6aae6898963468051b82d42 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;250&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_ebfef0737aead

# %%
Centro.save("003_mapa_CSF.html")
